# %% [markdown]
# ok the idea here is to make a knowledge graph from the english newspaper articles that donna sent.

# %%
import pandas as pd
import re
import spacy
import neuralcoref

# %%
# !python -m spacy download en_core_web_lg

# %%
#nlp = spacy.load('en_core_web_lg')

#from spacy.lang.en import English

import en_core_web_lg
nlp = en_core_web_lg.load()


neuralcoref.add_to_pipe(nlp)

# %%
def filter_spans(spans):
    # Filter a sequence of spans so they don't contain overlaps
    # For spaCy 2.1.4+: this function is available as spacy.util.filter_spans()
    get_sort_key = lambda span: (span.end - span.start, -span.start)
    sorted_spans = sorted(spans, key=get_sort_key, reverse=True)
    result = []
    seen_tokens = set()
    for span in sorted_spans:
        # Check for end - 1 here because boundaries are inclusive
        if span.start not in seen_tokens and span.end - 1 not in seen_tokens:
            result.append(span)
        seen_tokens.update(range(span.start, span.end))
    result = sorted(result, key=lambda span: span.start)
    return result

# %%
def get_entity_pairs(text, coref=True):
    # preprocess text
    text = re.sub(r'\n+', '.', text)  # replace multiple newlines with period
    text = re.sub(r'\[\d+\]', ' ', text)  # remove reference numbers
    text = nlp(text)
    if coref:
        text = nlp(text._.coref_resolved)  # resolve coreference clusters

    def refine_ent(ent, sent):
        unwanted_tokens = (
            'PRON',  # pronouns
            'PART',  # particle
            'DET',  # determiner
            'SCONJ',  # subordinating conjunction
            'PUNCT',  # punctuation
            'SYM',  # symbol
            'X',  # other
        )
        ent_type = ent.ent_type_  # get entity type
        if ent_type == '':
            ent_type = 'NOUN_CHUNK'
            ent = ' '.join(str(t.text) for t in
                           nlp(str(ent)) if t.pos_
                           not in unwanted_tokens and t.is_stop == False)
        elif ent_type in ('NOMINAL', 'CARDINAL', 'ORDINAL') and str(ent).find(' ') == -1:
            refined = ''
            for i in range(len(sent) - ent.i):
                if ent.nbor(i).pos_ not in ('VERB', 'PUNCT'):
                    refined += ' ' + str(ent.nbor(i))
                else:
                    ent = refined.strip()
                    break

        return ent, ent_type

    sentences = [sent.string.strip() for sent in text.sents]  # split text into sentences
    ent_pairs = []
    for sent in sentences:
        sent = nlp(sent)
        spans = list(sent.ents) + list(sent.noun_chunks)  # collect nodes
        spans = filter_spans(spans) 
        with sent.retokenize() as retokenizer:
            [retokenizer.merge(span, attrs={'tag': span.root.tag,
                                            'dep': span.root.dep}) for span in spans]
        deps = [token.dep_ for token in sent]

        # limit our example to simple sentences with one subject and object
        if (deps.count('obj') + deps.count('dobj')) != 1\
                or (deps.count('subj') + deps.count('nsubj')) != 1:
            continue

        for token in sent:
            if token.dep_ not in ('obj', 'dobj'):  # identify object nodes
                continue
            subject = [w for w in token.head.lefts if w.dep_
                       in ('subj', 'nsubj')]  # identify subject nodes
            if subject:
                subject = subject[0]
                # identify relationship by root dependency
                relation = [w for w in token.ancestors if w.dep_ == 'ROOT']
                if relation:
                    relation = relation[0]
                    # add adposition or particle to relationship
                    if relation.nbor(1).pos_ in ('ADP', 'PART'):
                        relation = ' '.join((str(relation), str(relation.nbor(1))))
                else:
                    relation = 'unknown'

                subject, subject_type = refine_ent(subject, sent)
                token, object_type = refine_ent(token, sent)

                ent_pairs.append([str(subject), str(relation), str(token),
                                  str(subject_type), str(object_type)])

    ent_pairs = [sublist for sublist in ent_pairs
                          if not any(str(ent) == '' for ent in sublist)]
    pairs = pd.DataFrame(ent_pairs, columns=['subject', 'relation', 'object',
                                             'subject_type', 'object_type'])
    print('Entity pairs extracted:', str(len(ent_pairs)))

    return pairs

# %%
import networkx as nx
import matplotlib.pyplot as plt


def draw_kg(pairs):
    k_graph = nx.from_pandas_edgelist(pairs, 'subject', 'object',
            create_using=nx.MultiDiGraph())
    node_deg = nx.degree(k_graph)
    layout = nx.spring_layout(k_graph, k=0.15, iterations=20)
    plt.figure(num=None, figsize=(30, 25), dpi=80)
    nx.draw_networkx(
        k_graph,
        node_size=[int(deg[1]) * 500 for deg in node_deg],
        arrowsize=20,
        linewidths=1.5,
        pos=layout,
        edge_color='red',
        edgecolors='black',
        node_color='white',
        )
    labels = dict(zip(list(zip(pairs.subject, pairs.object)),
                  pairs['relation'].tolist()))
    nx.draw_networkx_edge_labels(k_graph, pos=layout, edge_labels=labels,
                                 font_color='red', font_size=10)
    plt.axis('off')
    plt.show()

# %%
df = pd.read_csv (r'/Users/shawngraham/documents/yates-project/articles.csv')

# %%
display(df)
# Out:
#         ID               AUTHOR  \
# 0        1          Eva Hoffman
# 1        2      Herbert Mitgang
# 2        3         Jo Ann Lewis
# 3        4  The Washington Post
# 4        5         Philip Smith
# ...    ...                  ...
# 5289  5662          Paul Cherry
# 5290  5663          Jaimy Jones
# 5291  5664                  TNN
# 5292  5665        Duncan Barile
# 5293  5666          Lusi Banuve
#
#                                                   TITLE    YEAR DAY-MONTH  \
# 0                      A Tougher Policy On Art Imports?  1981.0    09-Jun
# 1         Recovered Peruvian Art Raises Cultural Issues  1982.0    08-May
# 2     Peru's Lost World's; 700 Art Treasures Find Th...  1982.0    08-May
# 3     Art Importer Fined, Given Year's Suspended Sen...  1982.0    03-Jun
# 4     Art Importer Guilty of Misdemeanor In Movement...  1982.0    27-Jan
# ...                                                 ...     ...       ...
# 5289  Bail hearing delayed for man accused in Montre...  2018.0    01-Mar
# 5290  Map experts in Clear Lake helped Christie's au...  2018.0    01-Mar
# 5291  5.75kg gold stolen from idol, police begin inv...  2018.0    01-Mar
# 5292  The Top Ten Most Important Ancient Documents L...  2018.0    01-Jan
# 5293  Votualevu Mandir Installs CCTV Cameras, Burgla...  2018.0    01-Apr
#
#                                                    TEXT
# 0     Ever since Lord Elgin took a fancy to some scu...
# 1     About 75 works of pre-Columbian art - gold fig...
# 2     On the morning of Jan. 16, 1981, U.S. Customs ...
# 3     A New York art importer who pleaded guilty to ...
# 4     A New York art importer whose goods were seize...
# ...                                                 ...
# 5289  A man who has made a career of pulling off hei...
# 5290  When a rare map purported to be from the 16th ...
# 5291  CHENNAI: The idol wing CID is looking into the...
# 5292  From Rome's holiest texts to a Chinese manuscr...
# 5293  We have invested in CCTV cameras, we have put ...
#
# [5294 rows x 6 columns]

# %%
final_data = df["TEXT"].map(lambda text: text if type(text)!=str else text.lower())

# %%
display(final_data)
# Out:
# 0       ever since lord elgin took a fancy to some scu...
# 1       about 75 works of pre-columbian art - gold fig...
# 2       on the morning of jan. 16, 1981, u.s. customs ...
# 3       a new york art importer who pleaded guilty to ...
# 4       a new york art importer whose goods were seize...
#                               ...
# 5289    a man who has made a career of pulling off hei...
# 5290    when a rare map purported to be from the 16th ...
# 5291    chennai: the idol wing cid is looking into the...
# 5292    from rome's holiest texts to a chinese manuscr...
# 5293    we have invested in cctv cameras, we have put ...
# Name: TEXT, Length: 5294, dtype: object

# %%
pairs = get_entity_pairs(final_data.loc[0])
# Out:
# Entity pairs extracted: 2

# %%
for i in range(0, final_data.shape[0]):
    pairs = pairs.append(get_entity_pairs(final_data.loc[i]))
# Out:
# Entity pairs extracted: 2
# Entity pairs extracted: 5
# Entity pairs extracted: 10
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 9
# Entity pairs extracted: 3
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 17
# Entity pairs extracted: 10
# Entity pairs extracted: 35
# Entity pairs extracted: 0
# Entity pairs extracted: 5
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 7
# Entity pairs extracted: 6
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 3
# Entity pairs extracted: 0
# Entity pairs extracted: 7
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 3
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 3
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 5
# Entity pairs extracted: 6
# Entity pairs extracted: 5
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 6
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 7
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 5
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 9
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 4
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 6
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 7
# Entity pairs extracted: 2
# Entity pairs extracted: 6
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 4
# Entity pairs extracted: 0
# Entity pairs extracted: 4
# Entity pairs extracted: 3
# Entity pairs extracted: 9
# Entity pairs extracted: 2
# Entity pairs extracted: 15
# Entity pairs extracted: 4
# Entity pairs extracted: 0
# Entity pairs extracted: 10
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 5
# Entity pairs extracted: 7
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 5
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 5
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 12
# Entity pairs extracted: 5
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 4
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 5
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 0
# Entity pairs extracted: 6
# Entity pairs extracted: 5
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 10
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 4
# Entity pairs extracted: 4
# Entity pairs extracted: 2
# Entity pairs extracted: 9
# Entity pairs extracted: 6
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 7
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 3
# Entity pairs extracted: 6
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 4
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 6
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 3
# Entity pairs extracted: 4
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 7
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 5
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 10
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 7
# Entity pairs extracted: 6
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 4
# Entity pairs extracted: 6
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 9
# Entity pairs extracted: 3
# Entity pairs extracted: 4
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 8
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 8
# Entity pairs extracted: 4
# Entity pairs extracted: 4
# Entity pairs extracted: 4
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 5
# Entity pairs extracted: 2
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 4
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 11
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 4
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 1
# Entity pairs extracted: 4
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 4
# Entity pairs extracted: 1
# Entity pairs extracted: 5
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 5
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 2
# Entity pairs extracted: 7
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 0
# Entity pairs extracted: 4
# Entity pairs extracted: 7
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 5
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 3
# Entity pairs extracted: 2
# Entity pairs extracted: 0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-43e931416e74> in <module>
#       1 for i in range(0, final_data.shape[0]):
# ----> 2     pairs = pairs.append(get_entity_pairs(final_data.loc[i]))
#
# <ipython-input-4-7344a74ef6ad> in get_entity_pairs(text, coref)
#      62                     relation = relation[0]
#      63                     # add adposition or particle to relationship
# ---> 64                     if relation.nbor(1).pos_ in ('ADP', 'PART'):
#      65                         relation = ' '.join((str(relation), str(relation.nbor(1))))
#      66                 else:
#
# token.pyx in spacy.tokens.token.Token.nbor()
#
# IndexError: [E042] Error accessing doc[7].nbor(1), for doc of length 8.

# %%
display(pairs)
# Out:
#              subject      relation           object subject_type object_type
# 0   native countries        caused  bitter disputes   NOUN_CHUNK  NOUN_CHUNK
# 1          countries        asking             help   NOUN_CHUNK  NOUN_CHUNK
# 0   native countries        caused  bitter disputes   NOUN_CHUNK  NOUN_CHUNK
# 1          countries        asking             help   NOUN_CHUNK  NOUN_CHUNK
# 0     art collectors          have           rights   NOUN_CHUNK  NOUN_CHUNK
# ..               ...           ...              ...          ...         ...
# 0           question  protected as        attention   NOUN_CHUNK  NOUN_CHUNK
# 1          secretary       visited       moon house   NOUN_CHUNK  NOUN_CHUNK
# 2            anasazi         built   small villages   NOUN_CHUNK  NOUN_CHUNK
# 0             police        issued           number   NOUN_CHUNK  NOUN_CHUNK
# 1             police       located  22 bronze coins   NOUN_CHUNK    CARDINAL
#
# [986 rows x 5 columns]

# %%
draw_kg(pairs)

# %%
# export graph to graphml

k_graph = nx.from_pandas_edgelist(pairs, 'subject', 'object',
            create_using=nx.MultiDiGraph())
nx.write_graphml(k_graph, "result.graphml")

# %%
k_graph = nx.from_pandas_edgelist(pairs, 'subject', 'object',
            create_using=nx.MultiDiGraph())
labels = dict(zip(list(zip(pairs.subject, pairs.object)),
                  pairs['relation'].tolist()))

# %%
f = open( 'edges_for_result-graphml.csv', 'w' )
f.write( repr(labels) + '\n' )
f.close()
