# %% [markdown]
# <a href="https://colab.research.google.com/github/shawngraham/kg/blob/main/autogenerated_knowledge_graph_from_wikipedia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# after this: https://towardsdatascience.com/auto-generated-knowledge-graphs-92ca99a81121

# %%
# !pip install wikipedia-api
# !pip install neuralcoref==4.0
# Out:
# Collecting wikipedia-api
#   Downloading Wikipedia-API-0.5.4.tar.gz (18 kB)
# Requirement already satisfied: requests in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from wikipedia-api) (2.25.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from requests->wikipedia-api) (1.26.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from requests->wikipedia-api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from requests->wikipedia-api) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from requests->wikipedia-api) (4.0.0)
# Building wheels for collected packages: wikipedia-api
#   Building wheel for wikipedia-api (setup.py) ... done
#   Created wheel for wikipedia-api: filename=Wikipedia_API-0.5.4-py3-none-any.whl size=13462 sha256=5e6c7a066838412d5bee2de814ca1edca6683b8c3c64ea0138e70311fbd5de30
#   Stored in directory: /Users/shawngraham/Library/Caches/pip/wheels/df/ef/26/efdbba65d2518a939c023f11f7d60a7f5d3405d47e51bbafdd
# Successfully built wikipedia-api
# Installing collected packages: wikipedia-api
# Successfully installed wikipedia-api-0.5.4
# Requirement already satisfied: neuralcoref==4.0 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (4.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from neuralcoref==4.0) (1.19.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from neuralcoref==4.0) (2.25.1)
# Requirement already satisfied: spacy>=2.1.0 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from neuralcoref==4.0) (2.1.0)
# Requirement already satisfied: boto3 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from neuralcoref==4.0) (1.17.14)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from requests<3.0.0,>=2.13.0->neuralcoref==4.0) (1.26.2)
# Requirement already satisfied: srsly<1.1.0,>=0.0.5 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (1.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.0.12 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (0.8.0)
# Requirement already satisfied: jsonschema<3.0.0,>=2.6.0 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (2.6.0)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (2.0.1)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (0.2.4)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (2.0.5)
# Requirement already satisfied: thinc<7.1.0,>=7.0.2 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (7.0.8)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (0.9.6)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from spacy>=2.1.0->neuralcoref==4.0) (1.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from thinc<7.1.0,>=7.0.2->spacy>=2.1.0->neuralcoref==4.0) (4.56.0)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from boto3->neuralcoref==4.0) (0.10.0)
# Requirement already satisfied: botocore<1.21.0,>=1.20.14 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from boto3->neuralcoref==4.0) (1.20.14)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from boto3->neuralcoref==4.0) (0.3.4)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.14->boto3->neuralcoref==4.0) (2.8.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/yates/lib/python3.6/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.21.0,>=1.20.14->boto3->neuralcoref==4.0) (1.15.0)

# %%
# !pip install spacy==2.1.0
# Out:
# Collecting spacy==2.1.0
#   Downloading https://files.pythonhosted.org/packages/62/39/4bde5da5f18ab0bdd525760c4fe38808b4bb03907a2aea094000d831afe1/spacy-2.1.0-cp36-cp36m-manylinux1_x86_64.whl (27.7MB)
#      |████████████████████████████████| 27.7MB 137kB/s
# Collecting plac<1.0.0,>=0.9.6
#   Downloading https://files.pythonhosted.org/packages/9e/9b/62c60d2f5bc135d2aa1d8c8a86aaf84edb719a59c7f11a4316259e61a298/plac-0.9.6-py2.py3-none-any.whl
# Requirement already satisfied: jsonschema<3.0.0,>=2.6.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.1.0) (2.6.0)
# Requirement already satisfied: srsly<1.1.0,>=0.0.5 in /usr/local/lib/python3.6/dist-packages (from spacy==2.1.0) (1.0.5)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.1.0) (1.19.5)
# Collecting preshed<2.1.0,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/20/93/f222fb957764a283203525ef20e62008675fd0a14ffff8cc1b1490147c63/preshed-2.0.1-cp36-cp36m-manylinux1_x86_64.whl (83kB)
#      |████████████████████████████████| 92kB 10.7MB/s
# Collecting blis<0.3.0,>=0.2.2
#   Downloading https://files.pythonhosted.org/packages/34/46/b1d0bb71d308e820ed30316c5f0a017cb5ef5f4324bcbc7da3cf9d3b075c/blis-0.2.4-cp36-cp36m-manylinux1_x86_64.whl (3.2MB)
#      |████████████████████████████████| 3.2MB 38.1MB/s
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.1.0) (2.0.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.1.0) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.1.0) (1.0.5)
# Collecting thinc<7.1.0,>=7.0.2
#   Downloading https://files.pythonhosted.org/packages/18/a5/9ace20422e7bb1bdcad31832ea85c52a09900cd4a7ce711246bfb92206ba/thinc-7.0.8-cp36-cp36m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 34.7MB/s
# Requirement already satisfied: wasabi<1.1.0,>=0.0.12 in /usr/local/lib/python3.6/dist-packages (from spacy==2.1.0) (0.8.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.0) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.1.0) (2020.12.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.1.0,>=7.0.2->spacy==2.1.0) (4.41.1)
# ERROR: en-core-web-sm 2.2.5 has requirement spacy>=2.2.2, but you'll have spacy 2.1.0 which is incompatible.
# ERROR: en-core-web-lg 2.2.5 has requirement spacy>=2.2.2, but you'll have spacy 2.1.0 which is incompatible.
# Installing collected packages: plac, preshed, blis, thinc, spacy
#   Found existing installation: plac 1.1.3
#     Uninstalling plac-1.1.3:
#       Successfully uninstalled plac-1.1.3
#   Found existing installation: preshed 3.0.5
#     Uninstalling preshed-3.0.5:
#       Successfully uninstalled preshed-3.0.5
#   Found existing installation: blis 0.4.1
#     Uninstalling blis-0.4.1:
#       Successfully uninstalled blis-0.4.1
#   Found existing installation: thinc 7.4.0
#     Uninstalling thinc-7.4.0:
#       Successfully uninstalled thinc-7.4.0
#   Found existing installation: spacy 2.2.4
#     Uninstalling spacy-2.2.4:
#       Successfully uninstalled spacy-2.2.4
# Successfully installed blis-0.2.4 plac-0.9.6 preshed-2.0.1 spacy-2.1.0 thinc-7.0.8

# %%
# !python -m spacy download en_core_web_lg
# https://stackoverflow.com/questions/56927602/unable-to-load-the-spacy-model-en-core-web-lg-on-google-colab
# then restart the runtime
# Out:
# Collecting en_core_web_lg==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-2.1.0/en_core_web_lg-2.1.0.tar.gz (826.9MB)
#      |████████████████████████████████| 826.9MB 1.2MB/s
# Building wheels for collected packages: en-core-web-lg
#   Building wheel for en-core-web-lg (setup.py) ... done
#   Created wheel for en-core-web-lg: filename=en_core_web_lg-2.1.0-cp36-none-any.whl size=828255077 sha256=f8ec7bde0be6eca5eb6aa2ac8ded5d481958c8f9568da2e1f635d90c29b29700
#   Stored in directory: /tmp/pip-ephem-wheel-cache-q4386lwh/wheels/b4/d7/70/426d313a459f82ed5e06cc36a50e2bb2f0ec5cb31d8e0bdf09
# Successfully built en-core-web-lg
# Installing collected packages: en-core-web-lg
#   Found existing installation: en-core-web-lg 2.2.5
#     Uninstalling en-core-web-lg-2.2.5:
#       Successfully uninstalled en-core-web-lg-2.2.5
# Successfully installed en-core-web-lg-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_lg')

# %%
import wikipediaapi  
import pandas as pd
import concurrent.futures
from tqdm import tqdm

def wiki_scrape(topic_name, verbose=True):
    def wiki_link(link):
        try:
            page = wiki_api.page(link)
            if page.exists():
                return {'page': link, 'text': page.text, 'link': page.fullurl,
                        'categories': list(page.categories.keys())}
        except:
            return None

    wiki_api = wikipediaapi.Wikipedia(language='en',
        extract_format=wikipediaapi.ExtractFormat.WIKI)
    page_name = wiki_api.page(topic_name)
    if not page_name.exists():
        print('Page {} does not exist.'.format(topic_name))
        return
    
    page_links = list(page_name.links.keys())
    progress = tqdm(desc='Links Scraped', unit='', total=len(page_links)) if verbose else None
    sources = [{'page': topic_name, 'text': page_name.text, 'link': page_name.fullurl,
                'categories': list(page_name.categories.keys())}]
    
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        future_link = {executor.submit(wiki_link, link): link for link in page_links}
        for future in concurrent.futures.as_completed(future_link):
            data = future.result()
            sources.append(data) if data else None
            progress.update(1) if verbose else None     
    progress.close() if verbose else None
    
    namespaces = ('Wikipedia', 'Special', 'Talk', 'LyricWiki', 'File', 'MediaWiki',
                  'Template', 'Help', 'User', 'Category talk', 'Portal talk')
    sources = pd.DataFrame(sources)
    sources = sources[(len(sources['text']) > 20)
                      & ~(sources['page'].str.startswith(namespaces, na=True))]
    sources['categories'] = sources.categories.apply(lambda x: [y[9:] for y in x])
    sources['topic'] = topic_name
    print('Wikipedia pages scraped:', len(sources))
    
    return sources

# %% [markdown]
# the original code below crashed the kernel all the time. i wondered if neuralcoref might be the issue; sure enough, people report kernel crashes, eg https://github.com/huggingface/neuralcoref/issues/207 so i tried installing an earlier version of spacy... and neuralcoref==4.0. Then, there was a missing function in spacy.utils, so I added it below, and pointed the rest of the code to use this function https://stackoverflow.com/questions/62259356/module-spacy-util-has-no-attribute-filter-spans-in-jupyter-notebook

# %%
import pandas as pd
import re
import spacy
import neuralcoref

#nlp = spacy.load('en_core_web_lg')

#from spacy.lang.en import English

import en_core_web_lg
nlp = en_core_web_lg.load()


neuralcoref.add_to_pipe(nlp)


def filter_spans(spans):
    # Filter a sequence of spans so they don't contain overlaps
    # For spaCy 2.1.4+: this function is available as spacy.util.filter_spans()
    get_sort_key = lambda span: (span.end - span.start, -span.start)
    sorted_spans = sorted(spans, key=get_sort_key, reverse=True)
    result = []
    seen_tokens = set()
    for span in sorted_spans:
        # Check for end - 1 here because boundaries are inclusive
        if span.start not in seen_tokens and span.end - 1 not in seen_tokens:
            result.append(span)
        seen_tokens.update(range(span.start, span.end))
    result = sorted(result, key=lambda span: span.start)
    return result


def get_entity_pairs(text, coref=True):
    # preprocess text
    text = re.sub(r'\n+', '.', text)  # replace multiple newlines with period
    text = re.sub(r'\[\d+\]', ' ', text)  # remove reference numbers
    text = nlp(text)
    if coref:
        text = nlp(text._.coref_resolved)  # resolve coreference clusters

    def refine_ent(ent, sent):
        unwanted_tokens = (
            'PRON',  # pronouns
            'PART',  # particle
            'DET',  # determiner
            'SCONJ',  # subordinating conjunction
            'PUNCT',  # punctuation
            'SYM',  # symbol
            'X',  # other
        )
        ent_type = ent.ent_type_  # get entity type
        if ent_type == '':
            ent_type = 'NOUN_CHUNK'
            ent = ' '.join(str(t.text) for t in
                           nlp(str(ent)) if t.pos_
                           not in unwanted_tokens and t.is_stop == False)
        elif ent_type in ('NOMINAL', 'CARDINAL', 'ORDINAL') and str(ent).find(' ') == -1:
            refined = ''
            for i in range(len(sent) - ent.i):
                if ent.nbor(i).pos_ not in ('VERB', 'PUNCT'):
                    refined += ' ' + str(ent.nbor(i))
                else:
                    ent = refined.strip()
                    break

        return ent, ent_type

    sentences = [sent.string.strip() for sent in text.sents]  # split text into sentences
    ent_pairs = []
    for sent in sentences:
        sent = nlp(sent)
        spans = list(sent.ents) + list(sent.noun_chunks)  # collect nodes
        spans = filter_spans(spans) 
        with sent.retokenize() as retokenizer:
            [retokenizer.merge(span, attrs={'tag': span.root.tag,
                                            'dep': span.root.dep}) for span in spans]
        deps = [token.dep_ for token in sent]

        # limit our example to simple sentences with one subject and object
        if (deps.count('obj') + deps.count('dobj')) != 1\
                or (deps.count('subj') + deps.count('nsubj')) != 1:
            continue

        for token in sent:
            if token.dep_ not in ('obj', 'dobj'):  # identify object nodes
                continue
            subject = [w for w in token.head.lefts if w.dep_
                       in ('subj', 'nsubj')]  # identify subject nodes
            if subject:
                subject = subject[0]
                # identify relationship by root dependency
                relation = [w for w in token.ancestors if w.dep_ == 'ROOT']
                if relation:
                    relation = relation[0]
                    # add adposition or particle to relationship
                    if relation.nbor(1).pos_ in ('ADP', 'PART'):
                        relation = ' '.join((str(relation), str(relation.nbor(1))))
                else:
                    relation = 'unknown'

                subject, subject_type = refine_ent(subject, sent)
                token, object_type = refine_ent(token, sent)

                ent_pairs.append([str(subject), str(relation), str(token),
                                  str(subject_type), str(object_type)])

    ent_pairs = [sublist for sublist in ent_pairs
                          if not any(str(ent) == '' for ent in sublist)]
    pairs = pd.DataFrame(ent_pairs, columns=['subject', 'relation', 'object',
                                             'subject_type', 'object_type'])
    print('Entity pairs extracted:', str(len(ent_pairs)))

    return pairs

# %%
import networkx as nx
import matplotlib.pyplot as plt


def draw_kg(pairs):
    k_graph = nx.from_pandas_edgelist(pairs, 'subject', 'object',
            create_using=nx.MultiDiGraph())
    node_deg = nx.degree(k_graph)
    layout = nx.spring_layout(k_graph, k=0.15, iterations=20)
    plt.figure(num=None, figsize=(30, 25), dpi=80)
    nx.draw_networkx(
        k_graph,
        node_size=[int(deg[1]) * 500 for deg in node_deg],
        arrowsize=20,
        linewidths=1.5,
        pos=layout,
        edge_color='red',
        edgecolors='black',
        node_color='white',
        )
    labels = dict(zip(list(zip(pairs.subject, pairs.object)),
                  pairs['relation'].tolist()))
    nx.draw_networkx_edge_labels(k_graph, pos=layout, edge_labels=labels,
                                 font_color='red', font_size=10)
    plt.axis('off')
    plt.show()

# %%
# sutton hoo
wiki_data = wiki_scrape('Giacomo_Medici_(art_dealer)')
# Out:
# Links Scraped: 100%|██████████| 27/27 [00:04<00:00,  5.42/s]
# Wikipedia pages scraped: 27

# %%
display(wiki_data)
# Out:
#                                                  page  \
# 0                         Giacomo_Medici_(art_dealer)
# 1                                   Antiquities trade
# 2                                          Art dealer
# 3                                   Cultural heritage
# 4                                         Carabinieri
# 19  Giacomo_Medici_(art_dealer)
# 20  Giacomo_Medici_(art_dealer)
# 21  Giacomo_Medici_(art_dealer)
# 22  Giacomo_Medici_(art_dealer)
# 23  Giacomo_Medici_(art_dealer)
# 24  Giacomo_Medici_(art_dealer)
# 25  Giacomo_Medici_(art_dealer)
# 27  Giacomo_Medici_(art_dealer)

# %% [markdown]
# ...need to lowercase the data. stem it too?

# %%
final_data = wiki_data["text"].map(lambda text: text if type(text)!=str else text.lower())

# %%
# something keeps breaking on the last line in the medici data frame, so i'm going to delete it


final_data.drop(final_data.tail(1).index,inplace=True) # drop last n rows

# %%
display(final_data)
# Out:
# 0     giacomo medici is an italian antiquities smugg...
# 1     the antiquities trade is the exchange of antiq...
# 2     an art dealer is a person or company that buys...
# 3     cultural heritage is the legacy of tangible an...
# 4     the carabinieri (, also us: , italian: [karabi...
# 5     ancient greece (greek: ἑλλάς, romanized: hellá...
# 6     the etruscan civilization () of ancient italy ...
# 7     geneva ( ji-nee-və; french: genève [ʒənɛv] (li...
# 8     the euro (symbol: €; code: eur) is the officia...
# 9     euphronios (greek: εὐφρόνιος; c. 535 – after 4...
# 10    the getty center, in los angeles, california, ...
# 11    marion true (born november 5, 1948) was the fo...
# 12    men's vogue was a monthly men's magazine that ...
# 13    military police (mp) are law enforcement agenc...
# 14    the metropolitan museum of art of new york cit...
# 15    pompeii (, latin: [pɔmˈpei̯.iː]) was an ancien...
# 16    peter frank patrick watson (born 23 april 1943...
# 17    robert emmanuel "bob" hecht, jr. (3 june 1919 ...
# 18    robin symes (born february 1939) is a now-disg...
# 19    red-figure vase painting is one of the most im...
# 20    the euphronios krater (or sarpedon krater) is ...
# 21    the carabinieri command for the protection of ...
# 22    sotheby's () is a british-founded american mul...
# 23    the roman empire (latin: imperium rōmānum [ɪmˈ...
# 24    the new york times (n.y.t. or n.y. times) is a...
# Name: text, dtype: object

# %%
#pairs = get_entity_pairs(wiki_data.loc[0,'text'])
pairs = get_entity_pairs(final_data.loc[0])

# iterate over everything?

for i in range(0, final_data.shape[0]):
    pairs = pairs.append(get_entity_pairs(final_data.loc[i]))
# Out:
# Entity pairs extracted: 0
# Entity pairs extracted: 0
# Entity pairs extracted: 1
# Entity pairs extracted: 5
# Entity pairs extracted: 5
# Entity pairs extracted: 16
# Entity pairs extracted: 26
# Entity pairs extracted: 14
# Entity pairs extracted: 35
# Entity pairs extracted: 9
# Entity pairs extracted: 19
# Entity pairs extracted: 19
# Entity pairs extracted: 7
# Entity pairs extracted: 4
# Entity pairs extracted: 55
# Entity pairs extracted: 42
# Entity pairs extracted: 18
# Entity pairs extracted: 3
# Entity pairs extracted: 1
# Entity pairs extracted: 2
# Entity pairs extracted: 58
# Entity pairs extracted: 2
# Entity pairs extracted: 3
# Entity pairs extracted: 18
# Entity pairs extracted: 77
# Entity pairs extracted: 52

# %%
display(pairs)
# Out:
#                                subject   relation  \
# 0                     space technology      offer
# 0   1567) job requirements.art dealers      study
# 1                              dealers  recognize
# 2                            galleries     charge
# 3                            galleries       hang
# ..                                 ...        ...
# 47                          2002 study   examined
# 48                               times  developed
# 49                         2012 report     called
# 50          pew research center survey      asked
# 51                     vicious assault     shakes
#
#                                object subject_type object_type
# 0                     suitable chance   NOUN_CHUNK  NOUN_CHUNK
# 0                             history   NOUN_CHUNK  NOUN_CHUNK
# 1                              styles   NOUN_CHUNK  NOUN_CHUNK
# 2                           flat rate   NOUN_CHUNK  NOUN_CHUNK
# 3                          solo shows   NOUN_CHUNK  NOUN_CHUNK
# ..                                ...          ...         ...
# 47               middle east coverage   NOUN_CHUNK  NOUN_CHUNK
# 48  national international reputation   NOUN_CHUNK  NOUN_CHUNK
# 49                              times   NOUN_CHUNK  NOUN_CHUNK
# 50                        respondents   NOUN_CHUNK  NOUN_CHUNK
# 51                         texas town   NOUN_CHUNK         GPE
#
# [491 rows x 5 columns]

# %%
pairs.to_csv('Giacomo_Medici.csv', encoding='utf-8', index=False)

# %%
draw_kg(pairs)

# write to graphml?

# %%
# export graph to graphml
k_graph = nx.from_pandas_edgelist(pairs, 'subject', 'object',
            create_using=nx.MultiDiGraph())
nx.write_graphml(k_graph, "result.graphml")

# check the graphml file; it seems to give all of the edges the same ID, so that'd have to be corrected brefore importing into gephi

# %%
def filter_graph(pairs, node):
    k_graph = nx.from_pandas_edgelist(pairs, 'subject', 'object',
            create_using=nx.MultiDiGraph())
    edges = nx.dfs_successors(k_graph, node)
    nodes = []
    for k, v in edges.items():
        nodes.extend([k])
        nodes.extend(v)
    subgraph = k_graph.subgraph(nodes)
    layout = (nx.random_layout(k_graph))
    nx.draw_networkx(
        subgraph,
        node_size=1000,
        arrowsize=20,
        linewidths=1.5,
        pos=layout,
        edge_color='red',
        edgecolors='black',
        node_color='white'
        )
    labels = dict(zip((list(zip(pairs.subject, pairs.object))),
                    pairs['relation'].tolist()))
    edges= tuple(subgraph.out_edges(data=False))
    sublabels ={k: labels[k] for k in edges}
    nx.draw_networkx_edge_labels(subgraph, pos=layout, edge_labels=sublabels,
                                font_color='red')
    plt.axis('off')
    plt.show()

# %%
filter_graph(pairs, 'grave robbers')

# %%
import trafilatura
downloaded = trafilatura.fetch_url('https://traffickingculture.org/encyclopedia/case-studies/giacomo-medici/')
medici = trafilatura.extract(downloaded)

# %%
pairs = get_entity_pairs(medici)
# Out:
# Entity pairs extracted: 6

# %%
display(pairs)
# Out:
#                     subject    relation                object subject_type  \
# 0          Sotheby’s London      opened         Hydra Gallery          ORG
# 1  the J. Paul Getty Museum    returned        Onesimos kylix          ORG
# 2                    Medici  consigning              material          ORG
# 3                    Medici   developed  commercial relations          ORG
# 4                 Sotheby’s    informed           Carabinieri          ORG
# 5               Carabinieri      raided         Medici’s home          ORG
#
#   object_type
# 0         ORG
# 1  NOUN_CHUNK
# 2  NOUN_CHUNK
# 3  NOUN_CHUNK
# 4  NOUN_CHUNK
# 5         ORG
